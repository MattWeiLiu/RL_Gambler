# %%
import numpy as np
from Play.GAME import LuxuryDiceGame
# Out:
# ---------------------------------- APP CONFIG ----------------------------------
# overflow:
#   size: 40000000
#   sequence: 20
# probabilityTable: [{'large': 4730, 'leopard': 510, 'small': 4760}, {'large': 4740, 'leopard': 480, 'small': 4780}, {'large': 4750, 'leopard': 450, 'small': 4800}, {'large': 4760, 'leopard': 430, 'small': 4810}]
# index_round: 100
# odds:
#   small: 2
#   leopard: 20
#   large: 2
# tax:
#   emergency: 0.01
#   loaded: 0.06
#   fair: 0.06
# safeline: 35000000
# loadedgate: 100000
# --------------------------------------------------------------------------------

# %%
env = LuxuryDiceGame()

# %%
for _ in range(1000):
    print("------------ 我是分隔線 ------------")
    large = np.random.randint(50000, 2500000)
    leopard = np.random.randint(10000, 1000000)
    small = np.random.randint(50000, 2500000)
    print(f"Large: {large}, Leopard: {leopard}, Small: {small}")
    call = env.draw(large=large, 
                    leopard=leopard, 
                    small=small)
    print(call)
    print("Current balance: ", env.balance)
# Out:
# ------------ 我是分隔線 ------------
# Large: 621035, Leopard: 982325, Small: 1750380
# Probability:  {'large': 4760, 'leopard': 430, 'small': 4810}
# Fair status
# large
# Current balance:  40303702.6
# ------------ 我是分隔線 ------------
# Large: 2295330, Leopard: 36827, Small: 1717460
# Probability:  {'large': 4760, 'leopard': 430, 'small': 4810}
# Fair status
# small
# Current balance:  44725039.58
# ------------ 我是分隔線 ------------
# Large: 1752685, Leopard: 642552, Small: 1415846
# Probability:  {'large': 4760, 'leopard': 430, 'small': 4810}
# Fair status
# small
# Current balance:  49286848.6
# ------------ 我是分隔線 ------------
# Large: 2002746, Leopard: 508323, Small: 1824279
# Probability:  {'large': 4760, 'leopard': 430, 'small': 4810}
# Fair status
# large
# Current balance:  53691931.72
# ------------ 我是分隔線 ------------
# Large: 1546210, Leopard: 27276, Small: 1962157
# Probability:  {'large': 4760, 'leopard': 430, 'small': 4810}
# Fair status
# small
# Current balance:  56626765.14
# ...
